# %%
import pandas as pd 
import numpy as np 

import prepare as p
import acquire as a

# %% [markdown]
# Use the function defined in acquire.py to load the Titanic data.
#
# Use the function defined in prepare.py to prepare the titanic data.

# %%
df = acquire.get_titanic_data()
# Out:
# this file exists, reading csv

# %%
def clean_titanic(df):
    """
    this clean up the dataset by droping colums and 
    chaning pclass to a object type 
    """
    #drop unncessary columns
    df = df.drop(columns=['passenger_id','embarked','age','deck', 'class'])

    #made this a string so its categorical
    df.pclass = df.pclass.astype(object)
    
    #filled nas with the mode
    df.embark_town = df.embark_town.fillna('Southampton')
    
    return df

# %%
clean_titanic(df)
# Out:
#      survived pclass     sex  sibsp  parch     fare  embark_town  alone
# 0           0      3    male      1      0   7.2500  Southampton      0
# 1           1      1  female      1      0  71.2833    Cherbourg      0
# 2           1      3  female      0      0   7.9250  Southampton      1
# 3           1      1  female      1      0  53.1000  Southampton      0
# 4           0      3    male      0      0   8.0500  Southampton      1
# ..        ...    ...     ...    ...    ...      ...          ...    ...
# 886         0      2    male      0      0  13.0000  Southampton      1
# 887         1      1  female      0      0  30.0000  Southampton      1
# 888         0      3  female      1      2  23.4500  Southampton      0
# 889         1      1    male      0      0  30.0000    Cherbourg      1
# 890         0      3    male      0      0   7.7500   Queenstown      1
#
# [891 rows x 8 columns]

# %% [markdown]
#  another way simple way
#
#  this will pull all of the data and clean and slipt the data with one go and will not need to put it into other one
#
#  t_train,t_val,t_test = p.clean_tit(a.get_titanic_data()),'survived '

# %%
df.shape
# Out:
# (891, 13)

# %%
df.embark_town.value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# Encode the categorical columns on train dataset. Create dummy variables of the categorical columns and concatenate them onto the dataframe. Remove the columns they are replacing. Repeat on validate and test.

# %%
df[['is_queenstown', 'is_southampton']] = pd.get_dummies(df.embark_town, drop_first=True).astype(int)

# %% [markdown]
# Create a function named preprocess_titanic that accepts the train, validate, and test titanic data, and returns the dataframes ready for modeling.

# %%
df.sample(10)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 816           816         0       3  female  23.0      0      0   7.9250
# 350           350         0       3    male  23.0      0      0   9.2250
# 840           840         0       3    male  20.0      0      0   7.9250
# 423           423         0       3  female  28.0      1      1  14.4000
# 317           317         0       2    male  54.0      0      0  14.0000
# 657           657         0       3  female  32.0      1      1  15.5000
# 223           223         0       3    male   NaN      0      0   7.8958
# 52             52         1       1  female  49.0      1      0  76.7292
# 410           410         0       3    male   NaN      0      0   7.8958
# 470           470         0       3    male   NaN      0      0   7.2500
#
#     embarked   class deck  embark_town  alone  is_queenstown  is_southampton
# 816        S   Third  NaN  Southampton      1              0               1
# ...

# %% [markdown]
# Use the function defined in acquire.py to load the Telco data.
#
# Use the function defined in prepare.py to prepare the Telco data

# %%
df_telco = acquire.get_telco_data()
df_telco
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# 7042                1                         1                 3  9995-HOTOH
#
# ...

# %%
prepare.prep_telco(df_telco)
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines online_security online_backup  ...  \
# 0              Yes                No              No           Yes  ...
# ...

# %% [markdown]
# Encode the categorical columns on train.
#
# Encode at least one column using .replace
#
# Encode at least one column using .map
#
# Encode the rest of the columns by creating dummy variables and concatenating them onto the dataframe.

# %%
df_telco.dtypes
# Out:
# payment_type_id               int64
# internet_service_type_id      int64
# contract_type_id              int64
# customer_id                  object
# gender                       object
# senior_citizen                int64
# partner                      object
# dependents                   object
# tenure                        int64
# phone_service                object
# multiple_lines               object
# online_security              object
# online_backup                object
# device_protection            object
# tech_support                 object
# streaming_tv                 object
# streaming_movies             object
# paperless_billing            object
# monthly_charges             float64
# total_charges                object
# churn                        object
# contract_type                object
# internet_service_type        object
# payment_type                 object
# Month_to_Month                int64
# Two years                     int64
# ...

# %%
df_telco.contract_type.value_counts() #going to drop two years
# Out:
# contract_type
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df_telco.internet_service_type.value_counts() # going to drop none
# Out:
# internet_service_type
# Fiber optic    3096
# DSL            2421
# None           1526
# Name: count, dtype: int64

# %%
df_telco[['Month_to_Month','Two years']] = pd.get_dummies(df_telco.contract_type,drop_first=True).astype(int)

# %%
df_telco
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# 7042                1                         1                 3  9995-HOTOH
#
# ...

# %%
df_telco[['is_fiber' 'is_dsl']] = pd.get_dummies(df_telco.internet_service_type,drop_first=True).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_telco[['is_fiber' 'is_dsl']] = pd.get_dummies(df_telco.internet_service_type,drop_first=True).astype(int)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3938, in DataFrame.__setitem__(self, key, value)
#    3936     self._setitem_frame(key, value)
#    3937 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3938     self._setitem_array(key, value)
#    3939 elif isinstance(value, DataFrame):
#    3940     self._set_item_frame_value(key, value)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3980, in DataFrame._setitem_array(self, key, value)
#    3975 else:
#    3976     # Note: unlike self.iloc[:, indexer] = value, this will
#    3977     #  never try to overwrite values inplace
# ...
