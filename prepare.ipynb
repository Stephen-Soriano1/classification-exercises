# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import acquire

# %% [markdown]
# Use the function defined in acquire.py to load the iris data.

# %%
# using one of the function i made to call the dataset
df_iris = acquire.get_iris_data()
# Out:
# this file exists, reading csv

# %%
df_iris.head()
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa

# %%
df_iris.columns
# Out:
# Index(['species_id', 'measurement_id', 'sepal_length', 'sepal_width',
#        'petal_length', 'petal_width', 'species_name'],
#       dtype='object')

# %% [markdown]
# Clean up the column names - replace the period with an underscore and lowercase.

# %%
# df_iris.colums.sts.replace('.','_', regex=False).str.lower()

# %% [markdown]
# Drop the species_id and measurement_id columns.

# %%
df_iris = df_iris.drop(columns='species_id')

# %%
df_iris = df_iris.drop(columns='measurement_id')

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species_name
# 0             5.1          3.5           1.4          0.2       setosa
# 1             4.9          3.0           1.4          0.2       setosa
# 2             4.7          3.2           1.3          0.2       setosa
# 3             4.6          3.1           1.5          0.2       setosa
# 4             5.0          3.6           1.4          0.2       setosa
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3    virginica
# 146           6.3          2.5           5.0          1.9    virginica
# 147           6.5          3.0           5.2          2.0    virginica
# 148           6.2          3.4           5.4          2.3    virginica
# 149           5.9          3.0           5.1          1.8    virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Rename the species_name column to just species.

# %%
df_iris = df_iris.rename(columns= {'species_name':'species'})

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris(df):
    '''this should be the clean and fix data set maybe could be improve '''
    
#     this is going to drop all the columns 
    df = df.drop(columns=['species_id','measurement_id'])
#    this is rename one of the colums
    df = df.rename(columns= {'species_name':'species'})
    
    return df

# %%
fresh_iris = acquire.get_iris_data()
# Out:
# this file exists, reading csv

# %% [markdown]
# Using the Telco dataset
#
# Use the function defined in acquire.py to load the Telco data.

# %%
df_telco = acquire.get_telco_data()
df_telco
# Out:
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# 7042                1                         1                 3  9995-HOTOH
#
#       gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0     Female               0     Yes        Yes       9           Yes  ...
# 1       Male               0      No         No       9           Yes  ...
# 2       Male               0      No         No       4           Yes  ...
# 3       Male               1     Yes         No      13           Yes  ...
# 4     Female               1     Yes         No       3           Yes  ...
# ...      ...             ...     ...        ...     ...           ...  ...
# 7038  Female               0      No         No      13           Yes  ...
# 7039    Male               0     Yes         No      22           Yes  ...
# 7040    Male               0      No         No       2           Yes  ...
# 7041    Male               0     Yes        Yes      67           Yes  ...
# 7042    Male               0     Yes        Yes      63            No  ...
#
#      tech_support streaming_tv streaming_movies paperless_billing  \
# 0             Yes          Yes               No               Yes
# 1              No           No              Yes                No
# 2              No           No               No               Yes
# 3              No          Yes              Yes               Yes
# 4             Yes          Yes               No               Yes
# ...           ...          ...              ...               ...
# 7038          Yes           No               No                No
# 7039           No           No              Yes               Yes
# 7040           No           No               No               Yes
# 7041          Yes           No              Yes                No
# 7042           No          Yes              Yes                No
#
#      monthly_charges total_charges churn   contract_type  \
# 0              65.60         593.3    No        One year
# 1              59.90         542.4    No  Month-to-month
# 2              73.90        280.85   Yes  Month-to-month
# 3              98.00       1237.85   Yes  Month-to-month
# 4              83.90         267.4   Yes  Month-to-month
# ...              ...           ...   ...             ...
# 7038           55.15         742.9    No        One year
# 7039           85.10        1873.7   Yes  Month-to-month
# 7040           50.30         92.75    No  Month-to-month
# 7041           67.85       4627.65    No        Two year
# 7042           59.00        3707.6    No        Two year
#
#       internet_service_type      payment_type
# 0                       DSL      Mailed check
# 1                       DSL      Mailed check
# 2               Fiber optic  Electronic check
# 3               Fiber optic  Electronic check
# 4               Fiber optic      Mailed check
# ...                     ...               ...
# 7038                    DSL      Mailed check
# 7039            Fiber optic  Electronic check
# 7040                    DSL      Mailed check
# 7041                    DSL      Mailed check
# 7042                    DSL  Electronic check
#
# [7043 rows x 24 columns]

# %% [markdown]
# Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.
#
# Handle null values.

# %%
# look at data first before just droping columns

# %%
df_telco.drop(columns='payment_type_id') 
#put it into a list to drop more[]
# Out:
#       internet_service_type_id  contract_type_id customer_id  gender  \
# 0                            1                 2  0002-ORFBO  Female
# 1                            1                 1  0003-MKNFE    Male
# 2                            2                 1  0004-TLHLJ    Male
# 3                            2                 1  0011-IGKFF    Male
# 4                            2                 1  0013-EXCHZ  Female
# ...                        ...               ...         ...     ...
# 7038                         1                 2  9987-LUTYD  Female
# 7039                         2                 1  9992-RRAMN    Male
# 7040                         1                 1  9992-UJOEL    Male
# 7041                         1                 3  9993-LHIEB    Male
# 7042                         1                 3  9995-HOTOH    Male
#
#       senior_citizen partner dependents  tenure phone_service  \
# 0                  0     Yes        Yes       9           Yes
# 1                  0      No         No       9           Yes
# 2                  0      No         No       4           Yes
# 3                  1     Yes         No      13           Yes
# 4                  1     Yes         No       3           Yes
# ...              ...     ...        ...     ...           ...
# 7038               0      No         No      13           Yes
# 7039               0     Yes         No      22           Yes
# 7040               0      No         No       2           Yes
# 7041               0     Yes        Yes      67           Yes
# 7042               0     Yes        Yes      63            No
#
#         multiple_lines  ... tech_support streaming_tv streaming_movies  \
# 0                   No  ...          Yes          Yes               No
# 1                  Yes  ...           No           No              Yes
# 2                   No  ...           No           No               No
# 3                   No  ...           No          Yes              Yes
# 4                   No  ...          Yes          Yes               No
# ...                ...  ...          ...          ...              ...
# 7038                No  ...          Yes           No               No
# 7039               Yes  ...           No           No              Yes
# 7040                No  ...           No           No               No
# 7041                No  ...          Yes           No              Yes
# 7042  No phone service  ...           No          Yes              Yes
#
#      paperless_billing monthly_charges total_charges churn   contract_type  \
# 0                  Yes           65.60         593.3    No        One year
# 1                   No           59.90         542.4    No  Month-to-month
# 2                  Yes           73.90        280.85   Yes  Month-to-month
# 3                  Yes           98.00       1237.85   Yes  Month-to-month
# 4                  Yes           83.90         267.4   Yes  Month-to-month
# ...                ...             ...           ...   ...             ...
# 7038                No           55.15         742.9    No        One year
# 7039               Yes           85.10        1873.7   Yes  Month-to-month
# 7040               Yes           50.30         92.75    No  Month-to-month
# 7041                No           67.85       4627.65    No        Two year
# 7042                No           59.00        3707.6    No        Two year
#
#      internet_service_type      payment_type
# 0                      DSL      Mailed check
# 1                      DSL      Mailed check
# 2              Fiber optic  Electronic check
# 3              Fiber optic  Electronic check
# 4              Fiber optic      Mailed check
# ...                    ...               ...
# 7038                   DSL      Mailed check
# 7039           Fiber optic  Electronic check
# 7040                   DSL      Mailed check
# 7041                   DSL      Mailed check
# 7042                   DSL  Electronic check
#
# [7043 rows x 23 columns]

# %%
df_telco.drop(columns='internet_service_type_id')
# Out:
#       payment_type_id  contract_type_id customer_id  gender  senior_citizen  \
# 0                   2                 2  0002-ORFBO  Female               0
# 1                   2                 1  0003-MKNFE    Male               0
# 2                   1                 1  0004-TLHLJ    Male               0
# 3                   1                 1  0011-IGKFF    Male               1
# 4                   2                 1  0013-EXCHZ  Female               1
# ...               ...               ...         ...     ...             ...
# 7038                2                 2  9987-LUTYD  Female               0
# 7039                1                 1  9992-RRAMN    Male               0
# 7040                2                 1  9992-UJOEL    Male               0
# 7041                2                 3  9993-LHIEB    Male               0
# 7042                1                 3  9995-HOTOH    Male               0
#
#      partner dependents  tenure phone_service    multiple_lines  ...  \
# 0        Yes        Yes       9           Yes                No  ...
# 1         No         No       9           Yes               Yes  ...
# 2         No         No       4           Yes                No  ...
# 3        Yes         No      13           Yes                No  ...
# 4        Yes         No       3           Yes                No  ...
# ...      ...        ...     ...           ...               ...  ...
# 7038      No         No      13           Yes                No  ...
# 7039     Yes         No      22           Yes               Yes  ...
# 7040      No         No       2           Yes                No  ...
# 7041     Yes        Yes      67           Yes                No  ...
# 7042     Yes        Yes      63            No  No phone service  ...
#
#      tech_support streaming_tv streaming_movies paperless_billing  \
# 0             Yes          Yes               No               Yes
# 1              No           No              Yes                No
# 2              No           No               No               Yes
# 3              No          Yes              Yes               Yes
# 4             Yes          Yes               No               Yes
# ...           ...          ...              ...               ...
# 7038          Yes           No               No                No
# 7039           No           No              Yes               Yes
# 7040           No           No               No               Yes
# 7041          Yes           No              Yes                No
# 7042           No          Yes              Yes                No
#
#      monthly_charges total_charges churn   contract_type  \
# 0              65.60         593.3    No        One year
# 1              59.90         542.4    No  Month-to-month
# 2              73.90        280.85   Yes  Month-to-month
# 3              98.00       1237.85   Yes  Month-to-month
# 4              83.90         267.4   Yes  Month-to-month
# ...              ...           ...   ...             ...
# 7038           55.15         742.9    No        One year
# 7039           85.10        1873.7   Yes  Month-to-month
# 7040           50.30         92.75    No  Month-to-month
# 7041           67.85       4627.65    No        Two year
# 7042           59.00        3707.6    No        Two year
#
#      internet_service_type      payment_type
# 0                      DSL      Mailed check
# 1                      DSL      Mailed check
# 2              Fiber optic  Electronic check
# 3              Fiber optic  Electronic check
# 4              Fiber optic      Mailed check
# ...                    ...               ...
# 7038                   DSL      Mailed check
# 7039           Fiber optic  Electronic check
# 7040                   DSL      Mailed check
# 7041                   DSL      Mailed check
# 7042                   DSL  Electronic check
#
# [7043 rows x 23 columns]

# %%
df_telco.drop(columns='contract_type_id')
# Out:
#       payment_type_id  internet_service_type_id customer_id  gender  \
# 0                   2                         1  0002-ORFBO  Female
# 1                   2                         1  0003-MKNFE    Male
# 2                   1                         2  0004-TLHLJ    Male
# 3                   1                         2  0011-IGKFF    Male
# 4                   2                         2  0013-EXCHZ  Female
# ...               ...                       ...         ...     ...
# 7038                2                         1  9987-LUTYD  Female
# 7039                1                         2  9992-RRAMN    Male
# 7040                2                         1  9992-UJOEL    Male
# 7041                2                         1  9993-LHIEB    Male
# 7042                1                         1  9995-HOTOH    Male
#
#       senior_citizen partner dependents  tenure phone_service  \
# 0                  0     Yes        Yes       9           Yes
# 1                  0      No         No       9           Yes
# 2                  0      No         No       4           Yes
# 3                  1     Yes         No      13           Yes
# 4                  1     Yes         No       3           Yes
# ...              ...     ...        ...     ...           ...
# 7038               0      No         No      13           Yes
# 7039               0     Yes         No      22           Yes
# 7040               0      No         No       2           Yes
# 7041               0     Yes        Yes      67           Yes
# 7042               0     Yes        Yes      63            No
#
#         multiple_lines  ... tech_support streaming_tv streaming_movies  \
# 0                   No  ...          Yes          Yes               No
# 1                  Yes  ...           No           No              Yes
# 2                   No  ...           No           No               No
# 3                   No  ...           No          Yes              Yes
# 4                   No  ...          Yes          Yes               No
# ...                ...  ...          ...          ...              ...
# 7038                No  ...          Yes           No               No
# 7039               Yes  ...           No           No              Yes
# 7040                No  ...           No           No               No
# 7041                No  ...          Yes           No              Yes
# 7042  No phone service  ...           No          Yes              Yes
#
#      paperless_billing monthly_charges total_charges churn   contract_type  \
# 0                  Yes           65.60         593.3    No        One year
# 1                   No           59.90         542.4    No  Month-to-month
# 2                  Yes           73.90        280.85   Yes  Month-to-month
# 3                  Yes           98.00       1237.85   Yes  Month-to-month
# 4                  Yes           83.90         267.4   Yes  Month-to-month
# ...                ...             ...           ...   ...             ...
# 7038                No           55.15         742.9    No        One year
# 7039               Yes           85.10        1873.7   Yes  Month-to-month
# 7040               Yes           50.30         92.75    No  Month-to-month
# 7041                No           67.85       4627.65    No        Two year
# 7042                No           59.00        3707.6    No        Two year
#
#      internet_service_type      payment_type
# 0                      DSL      Mailed check
# 1                      DSL      Mailed check
# 2              Fiber optic  Electronic check
# 3              Fiber optic  Electronic check
# 4              Fiber optic      Mailed check
# ...                    ...               ...
# 7038                   DSL      Mailed check
# 7039           Fiber optic  Electronic check
# 7040                   DSL      Mailed check
# 7041                   DSL      Mailed check
# 7042                   DSL  Electronic check
#
# [7043 rows x 23 columns]

# %%
# has no null vaule 
df_telco.isnull().sum()
# Out:
# payment_type_id             0
# internet_service_type_id    0
# contract_type_id            0
# customer_id                 0
# gender                      0
# senior_citizen              0
# partner                     0
# dependents                  0
# tenure                      0
# phone_service               0
# multiple_lines              0
# online_security             0
# online_backup               0
# device_protection           0
# tech_support                0
# streaming_tv                0
# streaming_movies            0
# paperless_billing           0
# monthly_charges             0
# total_charges               0
# churn                       0
# contract_type               0
# internet_service_type       0
# payment_type                0
# dtype: int64

# %%
df_telco = df_telco.total_charges.str.replace(' ','0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hb/7zd494kn7gl264gfmlh8nwrr0000gn/T/ipykernel_29559/2577648218.py in ?()
# ----> 1 df_telco = df_telco.total_charges.str.replace(' ','0')
#
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'total_charges'

# %% [markdown]
# Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def prep_telco(df):
#     handle the useless colums
    
    df = df.drop(columns='payment_type_id')
    df = df.drop(columns='internet_service_type_id')
    df = df.drop(columns='contract_type_id')
    
#     check to see if there any null
    df.isnull().sum()
    
#     get rid of the blank space
#     df = df.total_charges.str.replace(' ','0')
    return df

# %%
prep_telco(df_telco)
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines online_security online_backup  ...  \
# 0              Yes                No              No           Yes  ...
# 1              Yes               Yes              No            No  ...
# 2              Yes                No              No            No  ...
# 3              Yes                No              No           Yes  ...
# 4              Yes                No              No            No  ...
# ...            ...               ...             ...           ...  ...
# 7038           Yes                No             Yes            No  ...
# 7039           Yes               Yes              No            No  ...
# 7040           Yes                No              No           Yes  ...
# 7041           Yes                No             Yes            No  ...
# 7042            No  No phone service             Yes           Yes  ...
#
#      tech_support streaming_tv streaming_movies paperless_billing  \
# 0             Yes          Yes               No               Yes
# 1              No           No              Yes                No
# 2              No           No               No               Yes
# 3              No          Yes              Yes               Yes
# 4             Yes          Yes               No               Yes
# ...           ...          ...              ...               ...
# 7038          Yes           No               No                No
# 7039           No           No              Yes               Yes
# 7040           No           No               No               Yes
# 7041          Yes           No              Yes                No
# 7042           No          Yes              Yes                No
#
#      monthly_charges  total_charges churn   contract_type  \
# 0              65.60          593.3    No        One year
# 1              59.90          542.4    No  Month-to-month
# 2              73.90         280.85   Yes  Month-to-month
# 3              98.00        1237.85   Yes  Month-to-month
# 4              83.90          267.4   Yes  Month-to-month
# ...              ...            ...   ...             ...
# 7038           55.15          742.9    No        One year
# 7039           85.10         1873.7   Yes  Month-to-month
# 7040           50.30          92.75    No  Month-to-month
# 7041           67.85        4627.65    No        Two year
# 7042           59.00         3707.6    No        Two year
#
#      internet_service_type      payment_type
# 0                      DSL      Mailed check
# 1                      DSL      Mailed check
# 2              Fiber optic  Electronic check
# 3              Fiber optic  Electronic check
# 4              Fiber optic      Mailed check
# ...                    ...               ...
# 7038                   DSL      Mailed check
# 7039           Fiber optic  Electronic check
# 7040                   DSL      Mailed check
# 7041                   DSL      Mailed check
# 7042                   DSL  Electronic check
#
# [7043 rows x 21 columns]

# %% [markdown]
# split the data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
def splitting_data(df, col):
    
    '''this should be the first split the data with basic input'''
    
    train, validate_test = train_test_split(df,
                     train_size=0.6,
                     random_state=123,
                     stratify=df[col]
                    )
 
    
    
#     second split
    validate, test = train_test_split(validate_test,
                                     train_size=0.5,
                                      random_state=123,
                                      stratify=validate_test[col]
                        
                                     )
    return train,validate,test

# %%
iris_df = acquire.get_iris_data()

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df = prep_iris(iris_df)

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
train_iris, validate_iris, test_iris = splitting_data(iris_df, 'species')

# %%
# print(train_iris.shape)
# print(validate_iris.shape)
# print(test_iris.shape)
# Out:
# (90, 5)
# (30, 5)
# (30, 5)

# %% [markdown]
# Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %%
# species

# %% [markdown]
# Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %% [markdown]
# Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.
